# %% [markdown]
# # Open Access versions of articles in Australian HASS journals
#
# This is work-in-progress. I'm currently trying to work out why the Unpaywall API reports some articles as 'closed' when they are actually 'bronze'. This obviously affects some of the results below.

# %% [markdown]
# [How Unpaywall calculates OA status](https://support.unpaywall.org/support/solutions/articles/44001777288)

# %%
import requests
from requests.adapters import HTTPAdapter
from requests.packages.urllib3.util.retry import Retry
import requests_cache
from tqdm.auto import tqdm
import pandas as pd
import altair as alt
import collections

s = requests_cache.CachedSession()
retries = Retry(total=5, backoff_factor=1, status_forcelist=[ 502, 503, 504 ])
s.mount('https://', HTTPAdapter(max_retries=retries))
s.mount('http://', HTTPAdapter(max_retries=retries))

tqdm.pandas(desc="records")
# Out:
# /Users/tim/.pyenv/versions/3.8.5/envs/openaccess/lib/python3.8/site-packages/tqdm/std.py:697: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   from pandas import Panel

# %%
email = 'tim@discontents.com.au'

# %%
def get_total_results(issn):
    '''
    Get the total number of articles in CrossRef for this journal.
    '''
    response = s.get(f'https://api.crossref.org/journals/{issn}/works/', params={'rows': 0})
    data = response.json()
    try:
        total_works = data['message']['total-results']
    except KeyError:
        total_works = 0
    return total_works

def get_title(record):
    '''
    Titles are in a list – join any values
    '''
    title = record.get('title')
    if isinstance(title, list):
        title = ' – '.join(title)
    return title

def harvest_works(issn):
    '''
    Harvest basic details (DOI, title, date) of articles from the journal with the supplied ISSN from CrossRef.
    '''
    harvested = 0
    works = []
    total_results = get_total_results(issn)
    params = {
        'rows': 100,
        'offset': 0
    }
    headers = {
        'User-Agent': f'Jupyter Notebook (mailto:{email})'
    }
    with tqdm(total=total_results) as pbar:
        while harvested <= total_results:
            params['offset'] = harvested
            response = s.get(f'https://api.crossref.org/journals/{issn}/works/', params=params, headers=headers)
            data = response.json()
            try:
                records = data['message']['items']
            except TypeError:
                print('TYPEERROR')
                print(data)
            else:
                for record in records:
                    try:
                        works.append({'doi': record.get('DOI'), 'title': get_title(record), 'year': record['issued']['date-parts'][0][0]})
                    except KeyError:
                        print('KEYERROR')
                        print(record)
            harvested += 100
            pbar.update(len(data['message']['items']))
    return works

def get_oa_status(doi):
    '''
    Get OA status of DOI from the Unpaywall API.
    '''
    response = s.get(f'https://api.unpaywall.org/v2/{doi}?email={email}')
    data = response.json()
    return data['oa_status']

def create_scale(df):
    '''
    Set colour range to match the OA status types.
    '''
    scale = []
    colours = collections.OrderedDict()
    colours['hybrid'] = 'gold'
    colours['green'] = 'green'
    colours['bronze'] = 'brown'
    colours['closed'] = 'lightgrey'
    status_values = list(df['oa_status'].unique())
    for status, colour in colours.items():
        if status in status_values:
            scale.append(colour)
    return scale

def chart_oa_status(df, title):
    # Adding a numeric order column makes it easy to sort by oa_status
    df['order'] = df['oa_status'].replace({val: i for i, val in enumerate(['closed', 'bronze', 'green', 'hybrid'])})
    # Get colour values
    scale = create_scale(df)
    chart = alt.Chart(df).mark_bar().encode(
        x=alt.X('year:O', title='Year'),
        y=alt.Y('count():Q', title='Number of articles', axis=alt.Axis(tickMinStep=1)),
        color=alt.Color('oa_status:N', scale=alt.Scale(range=scale), legend=alt.Legend(title='OA type'), sort=alt.EncodingSortField('order', order='descending')),
        order='order',
        tooltip=[alt.Tooltip('count():Q', title='Number of articles'), alt.Tooltip('oa_status', title='OA type')]
    ).properties(title=title)
    display(chart)

# %% [markdown]
# ## Australian Historical Studies

# %%
works_ahs = harvest_works('1031-461X')
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=1548.0), HTML(value='')))

# %%
df_ahs = pd.DataFrame(works)
df_ahs.shape
# Out:
# (1548, 3)

# %%
# Make sure there's no duplicates
df_ahs.drop_duplicates(inplace=True)
df_ahs.shape
# Out:
# (1548, 3)

# %%
df_ahs['title'].value_counts()[:25]
# Out:
# Editorial board                                                                                    36
# Books                                                                                              35
# Book notes                                                                                         30
# In this issue                                                                                      20
# In This Issue                                                                                      16
# Notes on Contributors                                                                              16
# Exhibitions                                                                                        12
# Book reviews                                                                                       12
# Book Notes                                                                                         10
# Exhibition                                                                                          8
# Communications                                                                                      7
# Reviews                                                                                             6
# Exhibition review                                                                                   6
# Editorial Board                                                                                     6
# Exhibition reviews                                                                                  4
# Introduction                                                                                        4
# Book Note                                                                                           4
# Editorial                                                                                           4
# Notes on contributors                                                                               3
# BOOKS                                                                                               2
# Communication                                                                                       2
# Past Caring? Women, Work and Emotion                                                                1
# The Popular Culture of Romantic Love in Australia                                                   1
# ‘It was really moving, mate’: The Gallipoli Pilgrimage and Sentimental Nationalism in Australia     1
# Teenagers: The Rise of Youth Culture in New Zealand                                                 1
# Name: title, dtype: int64

# %%
# Get rid of titles that appear more than once
df_ahs_unique = df_ahs.copy().drop_duplicates(subset='title', keep=False)
df_ahs_unique.shape
# Out:
# (1305, 3)

# %%
df_ahs_unique['oa_status']  = df_ahs_unique['doi'].progress_apply(get_oa_status)
# Out:
# HBox(children=(HTML(value='records'), FloatProgress(value=0.0, max=1305.0), HTML(value='')))

# %%
df_ahs_unique['oa_status'].value_counts()
# Out:
# closed    1236
# green       36
# bronze      28
# hybrid       5
# Name: oa_status, dtype: int64

# %%
df_ahs_unique['oa_status'].value_counts(normalize=True).mul(100).round(1).astype(str) + '%'
# Out:
# closed    94.7%
# green      2.8%
# bronze     2.1%
# hybrid     0.4%
# Name: oa_status, dtype: object

# %%
chart_oa_status(df_ahs_unique, title='Australian Historical Studies')
# Out:
# alt.Chart(...)

# %% [markdown]
# ## History Australia

# %%
works_ha = harvest_works('1449-0854')
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=1249.0), HTML(value='')))

# %%
df_ha = pd.DataFrame(works_ha)
df_ha.shape
# Out:
# (1249, 3)

# %%
df_ha.drop_duplicates(inplace=True)
df_ha.shape
# Out:
# (1249, 3)

# %%
df_ha.loc[df_ha['title'].isnull()]
# Out:
#                             doi title  year
# 101   10.2104/ha.2007.4.issue-2  None  2007
# 214   10.2104/ha.2006.3.issue-1  None  2006
# 758   10.2104/ha.2008.5.issue-2  None  2008
# 867   10.2104/ha.2008.5.issue-3  None  2008
# 994   10.2104/ha.2006.3.issue-2  None  2006
# 1040  10.2104/ha.2007.4.issue-1  None  2007

# %%
df_ha.dropna(subset=['title'], inplace=True)
df_ha.shape
# Out:
# (1243, 3)

# %%
df_ha['title'].value_counts()[:30]
# Out:
# From the President                                                                                                      46
# From the Editors                                                                                                        35
# AHA Honour Roll                                                                                                         15
# Exhibition Reviews                                                                                                      14
# AHA Calendar of Events                                                                                                  12
# Book Reviews                                                                                                            11
# From the Editor                                                                                                         10
# AHA Prize and Award Winners                                                                                              9
# Australian Historical Association (AHA)                                                                                  5
# AHA Code of Conduct                                                                                                      4
# Film and Radio Reviews                                                                                                   4
# AHA Affiliates/Network                                                                                                   4
# Imprint information                                                                                                      3
# From the editors                                                                                                         3
# AHA Prizes and Awards                                                                                                    3
# AboutHistory Australia                                                                                                   3
# Film, Television, Radio and Theatre Reviews                                                                              3
# Review Policy for History Australia                                                                                      3
# From the Guest Editors                                                                                                   3
# AHA Prizes 2008                                                                                                          2
# AHA Prizes 2006 and Beyond                                                                                               2
# Submitting a manuscript to History Australia                                                                             2
# Prizes and Awards                                                                                                        2
# AHA Prizes 2009–10 in Brief                                                                                              2
# Submitting a manuscript toHistory Australia                                                                              2
# Introduction                                                                                                             2
# Damming the ‘Flood Evil’ on the Brisbane River                                                                           1
# Review of Conflicts 1945 to Today, Australian War Memorial, Canberra                                                     1
# Review of Peter Davis’ Pennies, Pokeys, Punks and the Prince’ and Tony Collins’ Pig City’, Hindsight, Radio National     1
# Mainstreaming money: perspectives on currency in the history of the British Isles                                        1
# Name: title, dtype: int64

# %%
df_ha_unique = df_ha.copy().drop_duplicates(subset='title', keep=False)
df_ha_unique.shape
# Out:
# (1039, 3)

# %%
df_ha_unique['oa_status']  = df_ha_unique['doi'].progress_apply(get_oa_status)
# Out:
# HBox(children=(HTML(value='records'), FloatProgress(value=0.0, max=1039.0), HTML(value='')))

# %%
df_ha_unique['oa_status'].value_counts()
# Out:
# closed    986
# green      27
# bronze     25
# hybrid      1
# Name: oa_status, dtype: int64

# %%
df_ha_unique['oa_status'].value_counts(normalize=True).mul(100).round(1).astype(str) + '%'
# Out:
# closed    94.9%
# green      2.6%
# bronze     2.4%
# hybrid     0.1%
# Name: oa_status, dtype: object

# %%
chart_oa_status(df_ha_unique, title='History Australia')
# Out:
# alt.Chart(...)

# %% [markdown]
# ## Australian Journal of Politics and History

# %%
works_ajph = harvest_works('1467-8497')
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=1944.0), HTML(value='')))

# %%
df_ajph = pd.DataFrame(works_ajph)
df_ajph.shape
# Out:
# (1944, 3)

# %%
df_ajph.drop_duplicates(inplace=True)
df_ajph.shape
# Out:
# (1944, 3)

# %%
df_ajph.loc[df_ajph['title'].isnull()]
# Out:
#                                doi title  year
# 57    10.1111/ajph.2008.54.issue-4  None  2008
# 63    10.1111/ajph.2009.55.issue-1  None  2009
# 80    10.1111/ajph.2008.54.issue-3  None  2008
# 86    10.1111/ajph.2000.46.issue-1  None  2000
# 87    10.1111/ajph.2002.48.issue-1  None  2002
# ...                            ...   ...   ...
# 1818            10.1111/ajph.v66.1  None  2020
# 1868            10.1111/ajph.v66.4  None  2020
# 1869            10.1111/ajph.v65.4  None  2019
# 1907            10.1111/ajph.v66.2  None  2020
# 1927            10.1111/ajph.v66.3  None  2020
#
# [157 rows x 3 columns]

# %%
df_ajph.dropna(subset=['title'], inplace=True)
df_ajph.shape
# Out:
# (1787, 3)

# %%
df_ajph['title'].value_counts()[:40]
# Out:
# Book Reviews                                                                                     106
# Book Notes                                                                                        52
# QUEENSLAND                                                                                        18
# SOUTH AUSTRALIA                                                                                   17
# VICTORIA                                                                                          17
# TASMANIA                                                                                          17
# Political Chronicles                                                                              16
# WESTERN AUSTRALIA                                                                                 15
# NEW SOUTH WALES                                                                                   15
# BOOK REVIEWS                                                                                      14
# Journal Notes                                                                                     11
# Issues in Australian Foreign Policy                                                               10
# Review Article                                                                                     8
# Issue Information                                                                                  8
# Australian Political Chronicle                                                                     5
# Problems of Australian Foreign Policy                                                              4
# THE COMMONWEALTH                                                                                   4
# Political Chronicle: Australia and Papua New Guinea                                                4
# Introduction                                                                                       4
# Queensland                                                                                         3
# Northern Territory                                                                                 3
# Books Received                                                                                     3
# Western Australia                                                                                  3
# ERRATA                                                                                             3
# THE TERRITORY OF PAPUA AND NEW GUINEA                                                              3
# Victoria                                                                                           2
# NORTHERN TERRITORY                                                                                 2
# PAPUA NEW GUINEA                                                                                   2
# Foreword                                                                                           2
# Tasmania                                                                                           2
# Other Books Received                                                                               2
# Commonwealth                                                                                       2
# Rejoinder                                                                                          2
# Volume Index                                                                                       2
# Problems in Australian Foreign Policy, July-December 1994                                          2
# South Australia                                                                                    2
# BOOK NOTES                                                                                         2
# THE WESTERN INTELLECTUAL TRADITION: From Leonardo to Hegel. By J. Bronowski and Bruce Mazlish      1
# Uncertain Climate: The Recent History of Drought Policy in Australia                               1
# A River with a City Problem: A History of Brisbane Floods                                          1
# Name: title, dtype: int64

# %%
df_ajph_unique = df_ajph.copy().drop_duplicates(subset='title', keep=False)
df_ajph_unique.shape
# Out:
# (1400, 3)

# %%
df_ajph_unique['oa_status']  = df_ajph_unique['doi'].progress_apply(get_oa_status)
# Out:
# HBox(children=(HTML(value='records'), FloatProgress(value=0.0, max=1400.0), HTML(value='')))

# %%
df_ajph_unique['oa_status'].value_counts()
# Out:
# closed    1340
# bronze      36
# green       22
# hybrid       2
# Name: oa_status, dtype: int64

# %%
df_ajph_unique['oa_status'].value_counts(normalize=True).mul(100).round(1).astype(str) + '%'
# Out:
# closed    95.7%
# bronze     2.6%
# green      1.6%
# hybrid     0.1%
# Name: oa_status, dtype: object

# %%
chart_oa_status(df_ajph_unique, title='Australian Journal of Politics and History')
# Out:
# alt.Chart(...)

# %% [markdown]
# ## Journal of Australian Studies
#
# ISSN: '1444-3058'

# %%
works_jas = harvest_works('1444-3058')
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=2113.0), HTML(value='')))

# %%
df_jas = pd.DataFrame(works_jas)
df_jas.shape
# Out:
# (2113, 3)

# %%
df_jas.drop_duplicates(inplace=True)
df_jas.shape
# Out:
# (2113, 3)

# %%
df_jas.loc[df_jas['title'].isnull()]
# Out:
# Empty DataFrame
# Columns: [doi, title, year]
# Index: []

# %%
df_jas.dropna(subset=['title'], inplace=True)
df_jas.shape
# Out:
# (2113, 3)

# %%
df_jas['title'].value_counts()[:30]
# Out:
# Editorial board                                                                                                                                         49
# Notes on contributors                                                                                                                                   40
# Notes                                                                                                                                                   32
# Contributors                                                                                                                                            31
# Notes on Contributors                                                                                                                                   28
# Reviews                                                                                                                                                 28
# Book reviews                                                                                                                                            27
# NOTES ON CONTRIBUTORS                                                                                                                                   19
# BOOK REVIEWS                                                                                                                                            16
# Introduction                                                                                                                                            16
# Editorial                                                                                                                                               12
# Short reviews and notices                                                                                                                               12
# JAS review of books                                                                                                                                     11
# John Barrett prize in Australian studies                                                                                                                10
# Erratum                                                                                                                                                  7
# The John Barrett Award for Australian Studies                                                                                                            6
# Book Reviews                                                                                                                                             5
# Editorial Board                                                                                                                                          5
# Acknowledgements                                                                                                                                         5
# Shorter notices and reviews                                                                                                                              5
# Foreword                                                                                                                                                 3
# Short notices and reviews                                                                                                                                2
# Biographical notes on contributors                                                                                                                       2
# Book review                                                                                                                                              2
# The John Barrett prize                                                                                                                                   2
# Shorter reviews and notices                                                                                                                              2
# Australian studies report                                                                                                                                2
# Acknowledgments                                                                                                                                          2
# “The book is inspired by the Australian soldier”: the wounds of war and the literary rehabilitation of the Australian soldier in Vietnam War writing     1
# Bodgies and Widgies — youth cultures in the 1950s∗                                                                                                       1
# Name: title, dtype: int64

# %%
df_jas_unique = df_jas.copy().drop_duplicates(subset='title', keep=False)
df_jas_unique.shape
# Out:
# (1732, 3)

# %%
df_jas_unique['oa_status']  = df_jas_unique['doi'].progress_apply(get_oa_status)
# Out:
# HBox(children=(HTML(value='records'), FloatProgress(value=0.0, max=1732.0), HTML(value='')))

# %%
df_jas_unique['oa_status'].value_counts()
# Out:
# closed    1632
# green       71
# bronze      26
# hybrid       3
# Name: oa_status, dtype: int64

# %%
df_jas_unique['oa_status'].value_counts(normalize=True).mul(100).round(1).astype(str) + '%'
# Out:
# closed    94.2%
# green      4.1%
# bronze     1.5%
# hybrid     0.2%
# Name: oa_status, dtype: object

# %%
chart_oa_status(df_jas_unique, title='Journal of Australian Studies')
# Out:
# alt.Chart(...)

# %% [markdown]
# ## Australian Archaeology
#
# ISSN: 0312-2417

# %%
works_aa = harvest_works('0312-2417')
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=1484.0), HTML(value='')))

# %%
df_aa = pd.DataFrame(works_aa)
df_aa.shape
# Out:
# (1484, 3)

# %%
df_aa.drop_duplicates(inplace=True)
df_aa.shape
# Out:
# (1484, 3)

# %%
df_aa.loc[df_aa['title'].isnull()]
# Out:
# Empty DataFrame
# Columns: [doi, title, year]
# Index: []

# %%
df_aa.dropna(subset=['title'], inplace=True)
df_aa.shape
# Out:
# (1484, 3)

# %%
df_aa['title'].value_counts()[:30]
# Out:
# Editorial                                                                                                                                                        57
# Book Reviews                                                                                                                                                     34
# Front Matter                                                                                                                                                     27
# Thesis Abstracts                                                                                                                                                 26
# Backfill                                                                                                                                                         23
# editorial                                                                                                                                                         8
# debitage                                                                                                                                                          7
# Debitage                                                                                                                                                          4
# Forthcoming Fieldwork                                                                                                                                             3
# Archaeologists and Aborigines                                                                                                                                     3
# Obituary                                                                                                                                                          3
# Fieldwork Calendar                                                                                                                                                3
# Thesis Abstract                                                                                                                                                   2
# Excavation Calendar                                                                                                                                               2
# A Technological Analysis Of Stone Artefacts From Big Foot Art Site, Cania Gorge, Central Queensland                                                               2
# Trench Shoring For Archaeologists And The Randwick Grave Digging Course                                                                                           2
# Obituaries                                                                                                                                                        2
# backfill                                                                                                                                                          2
# Front matter                                                                                                                                                      2
# Honours Theses in Prehistory                                                                                                                                      2
# The Aboriginal People of Tasmania, by Julia Clark                                                                                                                 2
# Fragments of What? Thoughts on the ‘Pieces of Paradise’ Exhibition at the Australian Museum                                                                       1
# Caveat Excavator: A Sea Bird Midden on Steep Head Island, North West Tasmania                                                                                     1
# Gledswood Shelter 1: Initial Radiocarbon Dates from a Pleistocene Aged Rockshelter Site in Northwest Queensland                                                   1
# A Dingo Burial From the Arnhem Land Plateau                                                                                                                       1
# AA Book Reviews                                                                                                                                                   1
# Reburial The British Way Skeleton service                                                                                                                         1
# Cave Archaeology and Sampling Issues in the Tropics: A Case Study from Lene Hara Cave, a 42,000 Year Old Occupation Site in East Timor, Island Southeast Asia     1
# Devil's Lair, A Study in Prehistory, by Charles Dortch                                                                                                            1
# Daughters of the Dreaming, by Diane Bell                                                                                                                          1
# Name: title, dtype: int64

# %%
df_aa_unique = df_aa.copy().drop_duplicates(subset='title', keep=False)
df_aa_unique.shape
# Out:
# (1268, 3)

# %%
df_aa_unique['oa_status']  = df_aa_unique['doi'].progress_apply(get_oa_status)
# Out:
# HBox(children=(HTML(value='records'), FloatProgress(value=0.0, max=1268.0), HTML(value='')))

# %%
df_aa_unique['oa_status'].value_counts()
# Out:
# closed    1057
# green      188
# bronze      21
# hybrid       2
# Name: oa_status, dtype: int64

# %%
df_aa_unique['oa_status'].value_counts(normalize=True).mul(100).round(1).astype(str) + '%'
# Out:
# closed    83.4%
# green     14.8%
# bronze     1.7%
# hybrid     0.2%
# Name: oa_status, dtype: object

# %%
chart_oa_status(df_aa_unique, title='Australian Archaeology')
# Out:
# alt.Chart(...)

# %% [markdown]
# ## Archives and Manuscripts
#
# ISSN: 0157-6895

# %%
works_am = harvest_works('0157-6895')
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=340.0), HTML(value='')))

# %%
df_am = pd.DataFrame(works_am)
df_am.shape
# Out:
# (340, 3)

# %%
df_am.drop_duplicates(inplace=True)
df_am.shape
# Out:
# (340, 3)

# %%
df_am.loc[df_am['title'].isnull()]
# Out:
# Empty DataFrame
# Columns: [doi, title, year]
# Index: []

# %%
df_am.dropna(subset=['title'], inplace=True)
df_am.shape
# Out:
# (340, 3)

# %%
df_am['title'].value_counts()[:30]
# Out:
# Editorial                                                                                                                                                          14
# Editorial Board                                                                                                                                                     3
# Archival Anxiety and the Vocational Calling                                                                                                                         2
# Corrigendum                                                                                                                                                         2
# Records and Information Management                                                                                                                                  2
# Unresolved issues: recordkeeping recommendations arising from Australian commissions of inquiry into the welfare of children in out-of-home care, 1997–2012         1
# Displaced Archives                                                                                                                                                  1
# Freedom of information and government records in Kenya, Uganda and Tanzania                                                                                         1
# Is digital different? How information creation, capture and discovery are being transformed                                                                         1
# Exploring the applicability of the Semantic Web for discovering and navigating Australian Indigenous knowledge resources                                            1
# The Handbook of Art and Design Librarianship, 2nd edn,                                                                                                              1
# Authenticity in places of belonging: community collective memory as a complex, adaptive recordkeeping system                                                        1
# From principle to practice: community consultation regarding access to Indigenous language material in archival records at the State Library of New South Wales     1
# A New Republic of Letters: Memory and Scholarship in the Age of Digital Reproduction                                                                                1
# Forging the future of special collections                                                                                                                           1
# Memory at stake – Swedish private archives in a changing landscape                                                                                                  1
# Chris Hurley’s stuff [website]                                                                                                                                      1
# #Cuéntalo: the path between archival activism and the social archive(s)                                                                                             1
# Disturbing the silence of women metal workers                                                                                                                       1
# The Bad-Ass Librarians of Timbuktu and Their Race to Save the World’s Most Precious Manuscripts                                                                     1
# Crisis, Credibility and Corporate History: Proceedings of the Symposium of the International Council on Archives                                                    1
# Archiving the wild, the wild archivist: Bukit Brown Cemetery and Singapore’s emerging ‘docu-tivists’                                                                1
# Dagmar Parer, 24 February 1948 – 4 November 2014                                                                                                                    1
# Michael John Saclier, 1937–2020                                                                                                                                     1
# Archive everything: mapping the everyday                                                                                                                            1
# Reinventing the concept of the state archival fond in China                                                                                                         1
# Affect in the archive: trauma, grief, delight and texts. Some personal reflections                                                                                  1
# Documenting sites of creation                                                                                                                                       1
# Perspectives on records and archives: an update from the Royal Commission                                                                                           1
# Setting the Record Straight for the Rights of the Child National Summit                                                                                             1
# Name: title, dtype: int64

# %%
df_am_unique = df_am.copy().drop_duplicates(subset='title', keep=False)
df_am_unique.shape
# Out:
# (317, 3)

# %%
df_am_unique['oa_status']  = df_am_unique['doi'].progress_apply(get_oa_status)
# Out:
# HBox(children=(HTML(value='records'), FloatProgress(value=0.0, max=317.0), HTML(value='')))

# %%
df_am_unique['oa_status'].value_counts()
# Out:
# closed    243
# bronze     46
# green      26
# hybrid      2
# Name: oa_status, dtype: int64

# %%
df_am_unique['oa_status'].value_counts(normalize=True).mul(100).round(1).astype(str) + '%'
# Out:
# closed    76.7%
# bronze    14.5%
# green      8.2%
# hybrid     0.6%
# Name: oa_status, dtype: object

# %%
chart_oa_status(df_am_unique, title='Archives and Manuscripts')
# Out:
# alt.Chart(...)

# %% [markdown]
# ## Journal of the Australian Library and Information Association
# Australian Academic and Research Libraries ISSN: 0004-8623
#
# Journal of ALIA ISSN: 2475-0158

# %%
works_aarn = harvest_works('0004-8623')
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=1335.0), HTML(value='')))

# %%
df = pd.DataFrame(works_aarn)
df.loc[df['year'] == 2000].shape
# Out:
# (32, 3)

# %%
works_jalia = harvest_works('2475-0158')
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=334.0), HTML(value='')))

# %%
df_jalia = pd.concat([pd.DataFrame(works_aarn), pd.DataFrame(works_jalia)]) 
df_jalia.shape
# Out:
# (1669, 3)

# %%
df_jalia.drop_duplicates(inplace=True)
df_jalia.shape
# Out:
# (1669, 3)

# %%
df_jalia.loc[df_jalia['title'].isnull()]
# Out:
# Empty DataFrame
# Columns: [doi, title, year]
# Index: []

# %%
df_jalia.dropna(subset=['title'], inplace=True)
df_jalia.shape
# Out:
# (1669, 3)

# %%
df_jalia['title'].value_counts()[:40]
# Out:
# Publications Received                                                                                                        66
# Book Reviews                                                                                                                 55
# Editorial                                                                                                                    50
# Front Matter                                                                                                                 26
# Reviews                                                                                                                      26
# Review Article                                                                                                               14
# Conference Reports                                                                                                            8
# Conference Report                                                                                                             8
# Book reviews                                                                                                                  6
# Obituary                                                                                                                      5
# Publications received                                                                                                         5
# Letters                                                                                                                       5
# Obituaries                                                                                                                    5
# New Australian Reference Books                                                                                                5
# Foreword                                                                                                                      5
# News                                                                                                                          4
# Letter                                                                                                                        4
# Book Review                                                                                                                   4
# Review Articles                                                                                                               4
# Letter to the Editor                                                                                                          3
# Processing the past: Contesting authority in history and the archives                                                         2
# Reports                                                                                                                       2
# Council of Australian University Librarians                                                                                   2
# Corrigendum                                                                                                                   2
# Editorial Board                                                                                                               2
# Teaching and Learning Spaces; Refurbishment of the W K Hancock Science Library at the Australian National University 2011     2
# Conferences                                                                                                                   2
# Information users and usability in the digital age                                                                            2
# Preface                                                                                                                       2
# Collection evaluation and the conspectus                                                                                      2
# Facilitating access to the web of data: A guide for librarians                                                                2
# Information Literacy Research: Dimensions of the Emerging Collective Consciousness                                            2
# Expert Internet Searching                                                                                                     2
# Building the Sustainable Library at Macquarie University                                                                      2
# CAUL annual survey of electronic retrieval systems                                                                            2
# Getting started with cloud computing                                                                                          2
# CAUL Report                                                                                                                   2
# Converging Technologies, Divergent Applications: The Future of Information Services to the Academic Community                 2
# The Special Collections Handbook                                                                                              2
# John Alexander Ferguson: Preserving our past, inspiring our future                                                            1
# Name: title, dtype: int64

# %%
df_jalia_unique = df_jalia.copy().drop_duplicates(subset='title', keep=False)
df_jalia_unique.shape
# Out:
# (1323, 5)

# %%
df_jalia_unique['oa_status']  = df_jalia_unique['doi'].progress_apply(get_oa_status)
# Out:
# HBox(children=(HTML(value='records'), FloatProgress(value=0.0, max=1323.0), HTML(value='')))

# %%
df_jalia_unique['oa_status'].value_counts()
# Out:
# closed    695
# bronze    561
# green      66
# hybrid      1
# Name: oa_status, dtype: int64

# %%
df_jalia_unique['oa_status'].value_counts(normalize=True).mul(100).round(1).astype(str) + '%'
# Out:
# closed    52.5%
# bronze    42.4%
# green      5.0%
# hybrid     0.1%
# Name: oa_status, dtype: object

# %%
chart_oa_status(df_jalia_unique, title='Journal of the Australian Library and Information Association')
# Out:
# alt.Chart(...)

# %%
df_jalia_unique.loc[df_jalia_unique['year'] == 2000]
# Out:
#                                  doi  \
# 667   10.1080/00048623.2000.10755120
# 687   10.1080/00048623.2000.10755130
# 697   10.1080/00048623.2000.10755137
# 701   10.1080/00048623.2000.10755134
# 742   10.1080/00048623.2000.10755109
# 750   10.1080/00048623.2000.10755118
# 752   10.1080/00048623.2000.10755115
# 753   10.1080/00048623.2000.10755112
# 755   10.1080/00048623.2000.10755108
# 758   10.1080/00048623.2000.10755117
# 761   10.1080/00048623.2000.10755107
# 770   10.1080/00048623.2000.10755116
# 771   10.1080/00048623.2000.10755128
# 780   10.1080/00048623.2000.10755129
# 781   10.1080/00048623.2000.10755124
# 783   10.1080/00048623.2000.10755123
# 784   10.1080/00048623.2000.10755126
# 785   10.1080/00048623.2000.10755125
# 797   10.1080/00048623.2000.10755133
# 809   10.1080/00048623.2000.10755132
# 821   10.1080/00048623.2000.10755131
# 1179  10.1080/00048623.2000.10755110
# 1282  10.1080/00048623.2000.10755127
#
#                                                   title  year oa_status  order
# 667                      Horst Kunze and Living History  2000    closed      0
# 687   Perfect One Day—Digital The Next: Challenges i...  2000    closed      0
# 697   Australian Library and Information Association...  2000    bronze      1
# 701   Documenting The Business of Government—Archiva...  2000    bronze      1
# 742   Library Provided Information and Clinical Deci...  2000    bronze      1
# 750   Improving Access for the Public to the Collect...  2000    closed      0
# 752                       Errata:The Chinese Advertiser  2000    bronze      1
# 753                           ALIA Vouchers and the GST  2000    closed      0
# 755   From Vision to Reality: The Evolution of a Lib...  2000     green      2
# 758   Passive Environmental Control for Small Cultur...  2000    bronze      1
# 761   Internet Training: Implications of an Internat...  2000    bronze      1
# 770   Benighted! How the University Library Survived...  2000    closed      0
# 771   We Would Live in Peace and Tranquility and No ...  2000    closed      0
# 780       Derek Fielding: A Select Bibliography 1956–96  2000    bronze      1
# 781                Derek Fielding A Biographical Sketch  2000    bronze      1
# 783                              About the Contributors  2000    closed      0
# 784         Higher Education: A Short History of Change  2000    bronze      1
# 785     Derek Fielding and the University of Queensland  2000    closed      0
# 797   ePreservation in the Archive: Theories, Practices  2000    bronze      1
# 809   Because It Belongs to All of Us: National Arra...  2000    bronze      1
# 821   Preserving the Past, Conceptualising the Futur...  2000    bronze      1
# 1179                               Industry Perspective  2000    closed      0
# 1282                            Libraries and Copyright  2000    bronze      1

# %% [markdown]
# ## Labour History
#
# ISSN: 0023-6942

# %%
works_lh = harvest_works('0023-6942')
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=2792.0), HTML(value='')))

# %%
df_lh = pd.DataFrame(works_lh)
df_lh.shape
# Out:
# (2792, 3)

# %%
df_lh.drop_duplicates(inplace=True)
df_lh.shape
# Out:
# (2792, 3)

# %%
df_lh.loc[df_lh['title'].isnull()]
# Out:
# Empty DataFrame
# Columns: [doi, title, year]
# Index: []

# %%
df_lh.dropna(subset=['title'], inplace=True)
df_lh.shape
# Out:
# (2792, 3)

# %%
df_lh['title'].value_counts()[:30]
# Out:
#                                                                                                                 280
# Review                                                                                                           54
# Front Matter                                                                                                     19
# Back Matter                                                                                                      17
# EDITORIAL                                                                                                         8
# Editorial                                                                                                         8
# Introduction                                                                                                      4
# Notice Board                                                                                                      3
# The Labor Government in the Second World War: A Memoir                                                            3
# Book Note                                                                                                         3
# Rejoinder                                                                                                         2
# Australian Popular Culture                                                                                        2
# Special Notice                                                                                                    2
# The Australian Society for the Study of Labour History: International Links                                       2
# The Eureka Stockade                                                                                               2
# Masters and Servants                                                                                              2
# The Emigration to Valparaiso in 1843                                                                              2
# Keep Moving                                                                                                       2
# The Workers' Union                                                                                                2
# The Study of Occupational Health in Australia                                                                     1
# Four Patterns of Convict Protest                                                                                  1
# Camden                                                                                                            1
# Friends of the People: Uneasy Radicals in the Age of the Chartists                                                1
# The Annihilation of the ILP: The Third Industrial Labor Party and the Sturt\nVacancy                              1
# The Negro and Organised Labor                                                                                     1
# How Labour Governs: A Study of Workers' Representation in Australia                                               1
# The Social History of Occupational Health                                                                         1
# Rethinking Labor Tradition: Synthesising Discourse and Experience                                                 1
# Making Working-Class Heroes: Labor Cartoonists and the Australian Worker, 1903-16                                 1
# Anarchism and State Violence in Sydney and Melbourne, 1886-1896: An Argument about Australian Labour History      1
# Name: title, dtype: int64

# %%
df_lh_unique = df_lh.copy().drop_duplicates(subset='title', keep=False)
df_lh_unique.shape
# Out:
# (2375, 3)

# %%
df_lh_unique['oa_status']  = df_lh_unique['doi'].progress_apply(get_oa_status)
# Out:
# HBox(children=(HTML(value='records'), FloatProgress(value=0.0, max=2375.0), HTML(value='')))

# %%
df_lh_unique['oa_status'].value_counts()
# Out:
# closed    2229
# green      146
# Name: oa_status, dtype: int64

# %%
df_lh_unique['oa_status'].value_counts(normalize=True).mul(100).round(1).astype(str) + '%'
# Out:
# closed    93.9%
# green      6.1%
# Name: oa_status, dtype: object

# %%
chart_oa_status(df_lh_unique, title='Labour History')
# Out:
# alt.Chart(...)
